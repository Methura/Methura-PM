# %%
import time
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix)
# 1. Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# 2. Load & Preprocess Dataset
df = pd.read_csv(r"Z:\Applied AI\bank-full1.csv")
df = df.replace("unknown", np.nan)
# Fill missing values
for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].fillna(df[col].mode()[0])
    else:
        df[col] = df[col].fillna(df[col].median())

# Encode target
df["y"] = df["y"].map({"yes": 1, "no": 0})

# One-hot encode categorical features
X = pd.get_dummies(df.drop("y", axis=1), drop_first=True)
y = df["y"]

# Standardize
scaler = StandardScaler()
X_processed = scaler.fit_transform(X)

# 3. Train / Validation / Test Split (70 / 15 / 15)
X_temp, X_test, y_temp, y_test = train_test_split(
    X_processed, y, test_size=0.15, random_state=SEED, stratify=y)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.1765, random_state=SEED, stratify=y_temp)  # 0.1765 of 85% ≈ 15%

input_dim = X_train.shape[1]
print("\n=== Dataset Split Check ===")
total = len(X_processed)
print(f"Train: {len(X_train)} ({len(X_train)/total:.2%})")
print(f"Validation: {len(X_val)} ({len(X_val)/total:.2%})")
print(f"Test: {len(X_test)} ({len(X_test)/total:.2%})")

# 4. Model Builder (Fixed Architecture)
def build_model(input_dim):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_dim,)),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(64, activation="relu"),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1, activation="sigmoid")])
return model

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True)

# 5. Training Function
def train_experiment(optimizer, batch_size, lr, momentum=None, nesterov=False):
    tf.keras.backend.clear_session()
    model = build_model(X_train.shape[1])

    if momentum is None:
        opt = optimizer(learning_rate=lr)
    else:
        opt = optimizer(learning_rate=lr, momentum=momentum, nesterov=nesterov)
   model.compile(optimizer=opt, loss="binary_crossentropy", metrics=["accuracy"])

    start = time.time()
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        epochs=200,
        callbacks=[early_stopping],
        verbose=0
    )
    total_time = time.time() - start
    return model, history.history, total_time

# 6. Optimizer Experiments
experiments = {
    "Batch GD": lambda: train_experiment(tf.keras.optimizers.SGD, len(X_train), 0.01),
    "SGD": lambda: train_experiment(tf.keras.optimizers.SGD, 8, 0.01),
    "Mini-Batch GD": lambda: train_experiment(tf.keras.optimizers.SGD, 32, 0.01),
    "Momentum": lambda: train_experiment(tf.keras.optimizers.SGD, 32, 0.01, momentum=0.9),
    "Nesterov": lambda: train_experiment(tf.keras.optimizers.SGD, 32, 0.01, momentum=0.9, nesterov=True)
}

results = {}
for name, fn in experiments.items():
    model, history, t = fn()
    results[name] = {"model": model, "history": history, "time": t}
    

# 7. Comparative Plots
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
for name in results:
    plt.plot(results[name]["history"]["val_loss"], label=name)
plt.title("Validation Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
for name in results:
    plt.plot(results[name]["history"]["val_accuracy"], label=name)
plt.title("Validation Accuracy vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# 8. Mini-Batch Size Study
batch_sizes = [16, 32, 128]
for bs in batch_sizes:
    _, h, t = train_experiment(tf.keras.optimizers.SGD, bs, 0.01)
    print(f"Mini-batch size {bs}: epochs={len(h['loss'])}, time={t:.2f}s")

# 9. Hyperparameter Sensitivity
print("\nSGD Learning Rate Sensitivity")
for lr in [0.001, 0.01, 0.1]:
    _, h, _ = train_experiment(tf.keras.optimizers.SGD, 32, lr)
    print(f"LR={lr}, epochs={len(h['loss'])}")

print("\nMomentum Sensitivity")
for m in [0.5, 0.9, 0.99]:
    _, h, _ = train_experiment(tf.keras.optimizers.SGD, 32, 0.01, momentum=m)
    print(f"Momentum={m}, epochs={len(h['loss'])}")

# 10. Test Set Evaluation (Best Optimizer: Nesterov)
best_model = results["Nesterov"]["model"]
y_pred = (best_model.predict(X_test) > 0.5).astype(int)

print("\nTest Set Performance (Nesterov)")
print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1-score :", f1_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# C:\Users\23adsb66\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.4754 - pr_auc: 0.2708 - roc_auc: 0.8753
# Epoch 2/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3299 - pr_auc: 0.4647 - roc_auc: 0.9494
# Epoch 3/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2524 - pr_auc: 0.5449 - roc_auc: 0.9653
# Epoch 4/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2171 - pr_auc: 0.5326 - roc_auc: 0.9651
# Epoch 5/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1873 - pr_auc: 0.4729 - roc_auc: 0.9767
# Epoch 6/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1658 - pr_auc: 0.5571 - roc_auc: 0.9785
# Epoch 7/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1593 - pr_auc: 0.4995 - roc_auc: 0.9832
# Epoch 8/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1469 - pr_auc: 0.4663 - roc_auc: 0.9867
# Epoch 9/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1348 - pr_auc: 0.5135 - roc_auc: 0.9885
# Epoch 10/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1417 - pr_auc: 0.5316 - roc_auc: 0.9867
# Epoch 11/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1441 - pr_auc: 0.5271 - roc_auc: 0.9851
# Epoch 12/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1277 - pr_auc: 0.5582 - roc_auc: 0.9900
# Epoch 13/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1242 - pr_auc: 0.5622 - roc_auc: 0.9905
# Epoch 14/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1116 - pr_auc: 0.5499 - roc_auc: 0.9924
# Epoch 15/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1131 - pr_auc: 0.5624 - roc_auc: 0.9922
# Epoch 16/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1219 - pr_auc: 0.5953 - roc_auc: 0.9908
# Epoch 17/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1131 - pr_auc: 0.5951 - roc_auc: 0.9918
# Epoch 18/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1241 - pr_auc: 0.5597 - roc_auc: 0.9905
# Epoch 19/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1014 - pr_auc: 0.5683 - roc_auc: 0.9941
# Epoch 20/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0976 - pr_auc: 0.5492 - roc_auc: 0.9943
# Epoch 21/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0988 - pr_auc: 0.5706 - roc_auc: 0.9942
# Epoch 22/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1148 - pr_auc: 0.5592 - roc_auc: 0.9921
# Epoch 23/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1019 - pr_auc: 0.5905 - roc_auc: 0.9936
# Epoch 24/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0997 - pr_auc: 0.5943 - roc_auc: 0.9936
# Epoch 25/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0933 - pr_auc: 0.5793 - roc_auc: 0.9947
# Epoch 26/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1033 - pr_auc: 0.6068 - roc_auc: 0.9936
# Epoch 27/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1006 - pr_auc: 0.5977 - roc_auc: 0.9929
# Epoch 28/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0924 - pr_auc: 0.5664 - roc_auc: 0.9947
# Epoch 29/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0788 - pr_auc: 0.6015 - roc_auc: 0.9962
# Epoch 30/30
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0810 - pr_auc: 0.5757 - roc_auc: 0.9958
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 746us/step
# [[55701  1163]
#  [    9    89]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.07      0.91      0.13        98
#
#     accuracy                           0.98     56962
#    macro avg       0.54      0.94      0.56     56962
# weighted avg       1.00      0.98      0.99     56962
#
# ROC-AUC: 0.9633003700917622
# PR-AUC: 0.7406950606045122
# Epoch 1/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0824 - pr_auc: 0.6065 - roc_auc: 0.9958 - val_loss: 0.0511 - val_pr_auc: 0.7733 - val_roc_auc: 0.9986
# Epoch 2/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0921 - pr_auc: 0.5973 - roc_auc: 0.9947 - val_loss: 0.0446 - val_pr_auc: 0.7727 - val_roc_auc: 0.9985
# Epoch 3/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1001 - pr_auc: 0.4040 - roc_auc: 0.9939 - val_loss: 0.0584 - val_pr_auc: 0.7207 - val_roc_auc: 0.9985
# Epoch 4/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0987 - pr_auc: 0.4918 - roc_auc: 0.9936 - val_loss: 0.0527 - val_pr_auc: 0.7295 - val_roc_auc: 0.9986
# Epoch 5/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0803 - pr_auc: 0.4980 - roc_auc: 0.9960 - val_loss: 0.0531 - val_pr_auc: 0.7192 - val_roc_auc: 0.9984
# Epoch 6/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0792 - pr_auc: 0.5244 - roc_auc: 0.9962 - val_loss: 0.0432 - val_pr_auc: 0.7530 - val_roc_auc: 0.9985
# Epoch 7/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0671 - pr_auc: 0.6002 - roc_auc: 0.9973 - val_loss: 0.0421 - val_pr_auc: 0.7321 - val_roc_auc: 0.9981
# Epoch 8/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0865 - pr_auc: 0.5491 - roc_auc: 0.9955 - val_loss: 0.0455 - val_pr_auc: 0.7145 - val_roc_auc: 0.9981
# Epoch 9/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0851 - pr_auc: 0.4822 - roc_auc: 0.9941 - val_loss: 0.0471 - val_pr_auc: 0.7041 - val_roc_auc: 0.9980
# Epoch 10/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0764 - pr_auc: 0.4928 - roc_auc: 0.9961 - val_loss: 0.0431 - val_pr_auc: 0.7020 - val_roc_auc: 0.9979
# Epoch 11/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0697 - pr_auc: 0.5539 - roc_auc: 0.9969 - val_loss: 0.0397 - val_pr_auc: 0.7040 - val_roc_auc: 0.9981
# Epoch 12/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0890 - pr_auc: 0.5327 - roc_auc: 0.9945 - val_loss: 0.0386 - val_pr_auc: 0.7104 - val_roc_auc: 0.9979
# Epoch 13/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0665 - pr_auc: 0.5381 - roc_auc: 0.9971 - val_loss: 0.0341 - val_pr_auc: 0.7350 - val_roc_auc: 0.9982
# Epoch 14/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0716 - pr_auc: 0.5550 - roc_auc: 0.9967 - val_loss: 0.0423 - val_pr_auc: 0.7090 - val_roc_auc: 0.9980
# Epoch 15/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0848 - pr_auc: 0.5534 - roc_auc: 0.9954 - val_loss: 0.0383 - val_pr_auc: 0.7282 - val_roc_auc: 0.9981
# Epoch 16/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0708 - pr_auc: 0.5496 - roc_auc: 0.9968 - val_loss: 0.0370 - val_pr_auc: 0.7173 - val_roc_auc: 0.9979
# Epoch 17/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0704 - pr_auc: 0.5436 - roc_auc: 0.9965 - val_loss: 0.0345 - val_pr_auc: 0.7268 - val_roc_auc: 0.9977
# Epoch 18/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0710 - pr_auc: 0.5627 - roc_auc: 0.9969 - val_loss: 0.0330 - val_pr_auc: 0.7422 - val_roc_auc: 0.9978
# Epoch 19/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0559 - pr_auc: 0.6358 - roc_auc: 0.9980 - val_loss: 0.0292 - val_pr_auc: 0.7518 - val_roc_auc: 0.9979
# Epoch 20/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0589 - pr_auc: 0.6305 - roc_auc: 0.9977 - val_loss: 0.0301 - val_pr_auc: 0.7521 - val_roc_auc: 0.9979
# Epoch 21/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0590 - pr_auc: 0.5973 - roc_auc: 0.9977 - val_loss: 0.0267 - val_pr_auc: 0.7523 - val_roc_auc: 0.9979
# Epoch 22/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0547 - pr_auc: 0.6026 - roc_auc: 0.9981 - val_loss: 0.0318 - val_pr_auc: 0.7009 - val_roc_auc: 0.9975
# Epoch 23/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0530 - pr_auc: 0.6132 - roc_auc: 0.9981 - val_loss: 0.0277 - val_pr_auc: 0.7159 - val_roc_auc: 0.9970
# Epoch 24/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0565 - pr_auc: 0.5151 - roc_auc: 0.9976 - val_loss: 0.0291 - val_pr_auc: 0.7149 - val_roc_auc: 0.9968
# Epoch 25/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0634 - pr_auc: 0.5514 - roc_auc: 0.9973 - val_loss: 0.0290 - val_pr_auc: 0.7414 - val_roc_auc: 0.9976
# Epoch 26/50
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0778 - pr_auc: 0.5833 - roc_auc: 0.9951 - val_loss: 0.0328 - val_pr_auc: 0.7442 - val_roc_auc: 0.9977
# C:\Users\23adsb66\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step
# C:\Users\23adsb66\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 642us/step
# C:\Users\23adsb66\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step
# C:\Users\23adsb66\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step
# C:\Users\23adsb66\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 1s 676us/step
# Mean ROC-AUC: 0.9821845013007481 +/- 0.008884560724038726
# Mean PR-AUC: 0.7481448236232814 +/- 0.03336064058705568
